# %% [markdown]
# ## exception handling

# %%
text="Hello! My name is Jawad Ahmad. I am learning Python, Artificial Intelligence, and Machine Learning. I am working hard to improve my programming skills and build a successful career in AI and ML."

# %%
#try:
with open("exercise.txt",'w') as f :
    f.write(text)
#except:

# %%
text="Hello! My name is Jawad Ahmad. I am learning Python, Artificial Intelligence, and Machine Learning. I am working hard to improve my programming skills and build a successful career in AI and ML."
#try:
with open("exercise.txt",'w') as f :
    f.write(text)
#except:
