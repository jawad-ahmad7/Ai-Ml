# %% [markdown]
# This section is all about variables ,variable types,dynamic typing ,type casting,variable name conventions

# %%
## variable decleration/assignation of value to variable
age=14
print(age)
# Out:
# 14

# %%
## variable types 
name='abullah'
age=23
height=172.8 
is_student=True
print(type(is_student))
# Out:
# <class 'bool'>

# %%
## name convention
''' 
It should be desciptive 
should start with letter or underscore
should have letters numbers underscore 
'''
# Out:
# ' \nIt should be desciptive \nshould start with letter or underscore\nshould have letters numbers underscore \n'

# %%
## type casting
age=32
print(type(age))
age=str(32)
print(type(age))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#dynamically typed language means variable type defined on run time 
age=10
print(type(age))
age='10'
print(type(age))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=10.1
age=int(10.1)
print(type(age))
print(age)
# Out:
# <class 'int'>
# 10
