# %% [markdown]
# This section is all about understanding of syntax,semantics,identations,single line,multiline comments in python

# %%
## This is a single line comment

# %%
'''
This is a multi line comment in python 
multiline comment
'''
# Out:
# '\nThis is a multi line comment in python \nmultiline comment\n'

# %%
## identation exampe 
age=int(input('Enter the age'))
if age>30:
    print('I am an adult')
else:
    print('i am a teen ')
# Out:
# i am a teen

# %%
#line continuation 
maths=1+2+3+4+5+6+\
    7+8+9+0
print(maths)
# Out:
# 45

# %%
## Type Infrencing 
name="""Abdullah"""
print(type(name))
name=10
print(type(name))
# Out:
# <class 'str'>
# <class 'int'>

# %%
#case sensitivity example 
name="Abdullah"
print(name)
Name='asad'
print(Name)
# Out:
# Abdullah
# asad
