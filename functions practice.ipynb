# %%
def sum_all(*numbers):
    print(f"Received {len(numbers)} numbers")
    total = sum(numbers)
    return total

# Call with different number of arguments
print("Sum of 1, 2, 3:", sum_all(1, 2, 3))
print("Sum of 10, 20:", sum_all(10, 20))
print("Sum of 5, 10, 15, 20, 25:", sum_all(5, 10, 15, 20, 25))

print()
# Out:
# Received 3 numbers
# Sum of 1, 2, 3: 6
# Received 2 numbers
# Sum of 10, 20: 30
# Received 5 numbers
# Sum of 5, 10, 15, 20, 25: 75

# %%
# Function that returns a value
def add_numbers(a, b):
    result = a + b
    return result

# Capture the returned value
sum1 = add_numbers(5, 3)
print(f"5 + 3 = {sum1}")

sum2 = add_numbers(10, 20)
print(f"10 + 20 = {sum2}")

# Use directly in expression
total = add_numbers(7, 8) + add_numbers(2, 3)
print(f"Total: {total}")
# Out:
# 5 + 3 = 8
# 10 + 20 = 30
# Total: 20

# %%
def print_info(**info):
    print("Information received:")
    for key, value in info.items():
        print(f"  {key}: {value}")
    print()   
print_info(name="jawad", age=25, city="peshawar")
print_info(product="Laptop", price=114.99, brand="dell")
# Out:
# Information received:
#   name: jawad
#   age: 25
#   city: peshawar
#
# Information received:
#   product: Laptop
#   price: 114.99
#   brand: dell

# %%
def sum(num1,num2,op):
    if op=='+':
        return num1 +num2
sum(num1=30, num2=70, op="+")
# Out:
# 100

# %%
def introduce_student(**student):
    print("name:",student['name'])
    print("age : "),student['age']
    print("address : ",student['address'])
introduce_student(name='jawad',age=22,address='peshawar')
# Out:
# name: jawad
# age :
# address :  peshawar
